# %% [markdown]
# <a href="https://colab.research.google.com/github/gkhulbe/gkhulberepository/blob/main/Blockbased_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Block based codes

# %%
# Conditions, Loops, Functions, Classes, ....

# %% [markdown]
# Conditions

# %%
if True:
    print("abcd")
    print("mnpq")

print("end of program")
# Out:
# abcd
# mnpq
# end of program

# %%
2 == 3
# Out:
# False

# %%
if 2 == 3-1:
    print('apple')
else:
    print('guava')
# Out:
# apple

# %%
2 < 3
# Out:
# True

# %%
if 2 > 3:
    print('apple')
else:
    print('guava')
# Out:
# guava

# %%
ls = [10,20,30,40]

# %%
100 in ls
# Out:
# False

# %%
if 100 in ls:
    print('apple')
else:
    print('guava')
# Out:
# guava

# %%
True + False
# Out:
# 1

# %%
True | False
# Out:
# True

# %%
True * False
# Out:
# 0

# %%
True & False
# Out:
# False

# %%
True | False & True | False
# Out:
# True

# %%
if True & False | False & True | False :
  print('apple')
else:
  print('hello')
# Out:
# hello

# %%
if ((40 in ls) | (100 in ls)):
   print('apple')
# Out:
# apple

# %%
# OR => |
# AND => &

# %%
if False:
  print('apple')
elif True:
  print('guava')
elif True:
  print('mango')
elif True:
  print('banana')
else:
  print('nothing')

print('end of code')
# Out:
# guava
# end of code

# %%
# condition, loops, functions, classes

# %%
#Based on the provided code cells, the concepts taught are primarily focused on Conditional Statements and Boolean Logic in Python. Specifically, the code demonstrates:

"""Basic if statements: How to execute code blocks based on a condition.
if-else statements: Providing alternative code execution paths.
if-elif-else chains: Handling multiple conditions sequentially.
Boolean values and comparisons: Using True, False, and comparison operators (==, >, <).
Logical operators: Using & (AND) and | (OR) to combine conditions, including examples of operator precedence.
Basic list usage: Creating a list and using the in operator to check for membership within a list.
Boolean arithmetic: Examples of True + False and True * False."""
