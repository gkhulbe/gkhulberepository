# %%
2 + 5
# Out:
# 7

# %%
'23' + '45'
# Out:
# '2345'

# %%
"abcd" + "mn"
# Out:
# 'abcdmn'

# %%
# pip vs uv

# %% [markdown]
# # In order to store any data we need variables
# - it follows certain rules

# %%
x = "this is python class"

# %%
x1 = "hello"

# %%
1x = "fasfasd"
# Out:
#   File "/tmp/ipykernel_5650/683400550.py", line 1
#     1x = "fasfasd"
#     ^
# SyntaxError: invalid decimal literal

# %%
x1
# Out:
# 'hello'

# %%
x_2 = "python"

# %%
_ = 4

# %%
_
# Out:
# 4

# %%
x_2
# Out:
# 'python'

# %%
x#2 = "fasfsdf"
# Out:
# 'this is python class'

# %%
st = "this is python"

# %%
"a" + "a"
# Out:
# 'aa'

# %%
2 + 2
# Out:
# 4

# %%
"10" + "10"
# Out:
# '1010'

# %%
"10" + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5650/453981478.py in <cell line: 0>()
# ----> 1 "10" + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = 10

# %%
y = "20"

# %%
"x" + y
# Out:
# 'x20'

# %%
str(x) + y
# Out:
# '1020'

# %%
x + int(y)
# Out:
# 30

# %%
v = 12 + 0.3

# %%
v2 = 0.1 + 0.2

# %%
c = (2 + 3j) + (10 + 1j)

# %%
True + 10
# Out:
# 11

# %%
type(x)
# Out:
# int

# %%
b = True

# %%
type(b + 10)
# Out:
# int
