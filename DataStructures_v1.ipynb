# %% [markdown]
# <a href="https://colab.research.google.com/github/gkhulbe/gkhulberepository/blob/main/DataStructures_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tuple, List, Sets, Dictionary

# %%
v = 10,20,30,20

# %%
v
# Out:
# (10, 20, 30, 20)

# %%
x, y, z = 'abcd', 'manago', 13

# %%
z
# Out:
# 13

# %%
f=33

# %%
x,y,z,f
# Out:
# ('abcd', 'manago', 13, 33)

# %%
v = 10,20,30,20,'mango'

# %%
len(v)
# Out:
# 5

# %%
type(v)
# Out:
# tuple

# %%
v[0] # indexing ... to find out what is at ) position
# Out:
# 10

# %%
v.index(20)
# Out:
# 1

# %%
v.count(20)
# Out:
# 2

# %%
# list

# %%
ls = [10,20,30,40,20,'mango']

# %%
ls.append('apple')

# %%
ls
# Out:
# [10, 20, 30, 40, 20, 'mango', 'apple']

# %%
ls.remove(10)

# %%
ls
# Out:
# [20, 30, 40, 20, 'mango', 'apple']

# %%
ls.insert(2, 'guava')

# %%
ls
# Out:
# [20, 30, 'guava', 40, 20, 'mango', 'apple']

# %%
ls.append(50)

# %%
ls
# Out:
# [20, 30, 'guava', 40, 20, 'mango', 'apple', 50]

# %%
ls.pop(4)
# Out:
# 'apple'

# %%
ls
# Out:
# [20, 30, 'guava', 40, 50]

# %%
ll = [20,1,13,7]

# %%
ll.sort(reverse=True)

# %%
ll
# Out:
# [20, 13, 7, 1]

# %%
kl = ['a', '01', '00', '0', '0a','mango', '2','100']

# %%
kl.sort(reverse=False)

# %%
kl
# Out:
# ['0', '00', '01', '0a', '100', '2', 'a', 'mango']

# %%
ms = ['100', "002", "apple", "Apple"]

# %%
ms.sort()

# %%
ms
# Out:
# ['002', '100', 'Apple', 'apple']

# %% [markdown]
# # Extend

# %%
[10, 20, 30] + [50, 60]
# Out:
# [10, 20, 30, 50, 60]

# %%
ls = [10,20,30]
ll = [50]

# %%
ls.extend(ll)
ls
# Out:
# [10, 20, 30, 50]

# %% [markdown]
# # extend with string

# %%
ls
# Out:
# [20, 30, 'guava', 40, 50, 20, 13, 7, 1, 20, 13, 7, 1]

# %%
list('mango')
# Out:
# ['m', 'a', 'n', 'g', 'o']

# %%
ls.extend('mango788')

# %%
ls
# Out:
# [10, 20, 30, 50, 'm', 'a', 'n', 'g', 'o', '7', '8', '8']

# %% [markdown]
# # copying

# %%
lm = ls # deep copy

# %%
ls.remove('a')

# %%
ls
# Out:
# [10, 20, 30, 50, 'm', 'n', 'g', 'o']

# %%
lm
# Out:
# [10, 20, 30, 50, 'm', 'n', 'g', 'o']

# %%
lk = ls.copy() # temp copy or shallow copy

# %%
ls.append('e')

# %%
ls
# Out:
# [10, 20, 30, 50, 'm', 'n', 'g', 'o', 'e']

# %%
lk
# Out:
# [10, 20, 30, 50, 'm', 'n', 'g', 'o']
