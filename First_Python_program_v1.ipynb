# %% [markdown]
# <a href="https://colab.research.google.com/github/gkhulbe/gkhulberepository/blob/main/First_Python_program_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 + 5
# Out:
# 7

# %%
'23' + '45'
# Out:
# '2345'

# %%
"abcd" + "mn"
# Out:
# 'abcdmn'

# %%
# pip vs uv

# %% [markdown]
# # In order to store any data we need variables
# - it follows certain rules

# %%
x = "this is python class"

# %%
x1 = "hello"

# %%
1x = "fasfasd"
# Out:
#   File "/tmp/ipykernel_12020/683400550.py", line 1
#     1x = "fasfasd"
#     ^
# SyntaxError: invalid decimal literal

# %%
x1

# %%
x_2 = "python"

# %%
_ = 4

# %%
_

# %%
x_2

# %%
x#2 = "fasfsdf"

# %%
st = "this is python"

# %%
"a" + "a"

# %%
2 + 2

# %%
"10" + "10"

# %%
"10" + 10

# %%
x = 10

# %%
y = "20"

# %%
"x" + y

# %%
str(x) + y

# %%
x + int(y)

# %%
v = 12 + 0.3

# %%
v2 = 0.1 + 0.2

# %%
c = (2 + 3j) + (10 + 1j)

# %%
True + 10
# Out:
# 11

# %%
type(x)
# Out:
# str

# %%
b = True

# %%
type(b + 10)
# Out:
# int

# %%
v3 = 'this is my teacher book'

# %%
print(v3)
# Out:
# this is my teacher book

# %%
st = """
    this is python
    python is extensively used in AI
    """

# %%
print(st)
# Out:
#     this is python
#     python is extensively used in AI

# %% [markdown]
# # Strings

# %%
st = "this is my python"

# %%
st.upper() # methods or casually functions
# Out:
# 'THIS IS MY PYTHON'

# %%
'''
this is teacher's notebook
'''
# Out:
# "\nthis is teacher's notebook\n"

# %%
"thIs iS pYtHon".swapcase()
# Out:
# 'THiS Is PyThON'

# %%
st
# Out:
# 'this is my python'

# %%
st.index('s', 4)
# Out:
# 6

# %%
st.rindex('s')
# Out:
# 6

# %%
st.find('z')
# Out:
# -1

# %%
st[5]
# Out:
# 'i'

# %%
len(st)
# Out:
# 17

# %%
st
# Out:
# 'this is my python'

# %%
st[-2]
# Out:
# 'o'

# %%
st[-17]
# Out:
# 't'

# %%
st[16]
# Out:
# 'n'

# %%
st
# Out:
# 'this is my python'

# %%
st[2:-3] # 14 -2 = 12
# Out:
# 'is is my pyt'

# %%
st[2:14:2]
# Out:
# 'i sm y'

# %%
st
# Out:
# 'this is my python'

# %%
st[13:1:-2]
# Out:
# 'tpy is'
